# %% [markdown]
# ## GeoTIFFs to single netCDF with time dimension enabled
#
# ---
# Convert CHIRPS GeoTIFF in a folder to single NetCDF file with time dimension enabled that is CF-Compliant
# http://cfconventions.org/cf-conventions/v1.6.0/cf-conventions.html
#
# Based on Rich Signell's answer on StackExchange: https://gis.stackexchange.com/a/70487
# This script was tested using CHIRPS dekad data. Adjustment is needed if using other timesteps data for CHIRPS
# NCO (http://nco.sourceforge.net) must be installed before using this script
#
# Modified by
# Benny Istanto, UN World Food Programme, benny.istanto@wfp.org
#
# ---

# %% [markdown]
# ### CHIRPS Java Monthly
#
# Case Java island, Indonesia - 105.05,116,25,-8.80,-5.05
#
# Original data in GeoTIFF format downloaded from https://data.chc.ucsb.edu/products/CHIRPS-2.0/global_monthly/tifs/
# Then clipped using Java boundary (https://www.dropbox.com/s/bgz8p4dz5hcwn9d/java_bnd_chirps_subset.zip?dl=0) via gdalwarp
#  - ```for i in `find *.tif`; do gdalwarp --config GDALWARP_IGNORE_BAD_CUTLINE YES -srcnodata NoData -dstnodata -9999 -cutline java_bnd_chirps_subset.shp -crop_to_cutline $i java_$i; done```
#
# Clipped GeoTIFF file for Java (https://www.dropbox.com/sh/kgt1ixcbmuh0ovs/AAAnsDcl4ELOexG4Ft1mVlHMa?dl=0)

# %%
#!/usr/bin/env python
import numpy as np
import datetime as dt
import os
import gdal
import netCDF4
import re

# %%
ds = gdal.Open('/Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1981.01.tif')

# %%
a = ds.ReadAsArray()
nlat,nlon = np.shape(a)

# %%
b = ds.GetGeoTransform() #bbox, interval
lon = np.arange(nlon)*b[1]+b[0]
lat = np.arange(nlat)*b[5]+b[3]

basedate = dt.datetime(1980,1,1,0,0,0)

# %%
# create NetCDF file
nco = netCDF4.Dataset('java_cli_chirps_1months_1981_2020.nc','w',clobber=True)

# create dimensions, variables and attributes:
nco.createDimension('lon',nlon)
nco.createDimension('lat',nlat)
nco.createDimension('time',None)

timeo = nco.createVariable('time','f4',('time'))
timeo.units = 'days since 1980-1-1 00:00:00'
timeo.standard_name = 'time'
timeo.calendar = 'gregorian'
timeo.axis = 'T'

lono = nco.createVariable('lon','f4',('lon'))
lono.units = 'degrees_east'
lono.standard_name = 'longitude'
lono.long_name = 'longitude'
lono.axis = 'X'

lato = nco.createVariable('lat','f4',('lat'))
lato.units = 'degrees_north'
lato.standard_name = 'latitude'
lato.long_name = 'latitude'
lato.axis = 'Y'

# create container variable for CRS: lon/lat WGS84 datum
crso = nco.createVariable('crs','i4')
crso.long_name = 'Lon/Lat Coords in WGS84'
crso.grid_mapping_name='latitude_longitude'
crso.longitude_of_prime_meridian = 0.0
crso.semi_major_axis = 6378137.0
crso.inverse_flattening = 298.257223563

# create short integer variable for precipitation data, with chunking
pcpo = nco.createVariable('precip', 'f4',  ('time', 'lat', 'lon'),zlib=True,fill_value=-9999.)
pcpo.units = 'mm'
pcpo.standard_name = 'convective precipitation rate'
pcpo.long_name = 'Climate Hazards group InfraRed Precipitation with Stations'
pcpo.time_step = 'month'
pcpo.missing_value = -9999.
pcpo.geospatial_lat_min = -8.8
pcpo.geospatial_lat_max = -5.05
pcpo.geospatial_lon_min = 105.05
pcpo.geospatial_lon_max = 116.25
pcpo.grid_mapping = 'crs'
pcpo.set_auto_maskandscale(False)

nco.Conventions='CF-1.6'
nco.title = "CHIRPS v2.0"
nco.history = "created by Climate Hazards Group. University of California at Santa Barbara"
nco.version = "Version 2.0"
nco.comments = "time variable denotes the first day of the given dekad."
nco.website = "https://www.chc.ucsb.edu/data/chirps"
nco.date_created = "2021-01-08"
nco.creator_name = "Benny Istanto"
nco.creator_email = "benny.istanto@wfp.org"
nco.institution = "UN World Food Programme"
nco.note = "The data is developed to support regular updating procedure for SPI analysis (https://github.com/wfpidn/SPI). This activities will support WFP to assess extreme dry and wet periods as part of WFP's Seasonal Monitoring"


#write lon,lat
lono[:]=lon
lato[:]=lat

pat = re.compile('java_chirps-v2.0.[0-9]{4}\.[0-9]{2}')
itime=0

#step through data, writing time and data to NetCDF
for root, dirs, files in os.walk('/Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/'):
    dirs.sort()
    files.sort()
    for f in files:
        if re.match(pat,f):
            # read the time values by parsing the filename
            year=int(f[17:21])
            mon=int(f[22:24])
            date=dt.datetime(year,mon,1,0,0,0)
            print(date)
            dtime=(date-basedate).total_seconds()/86400.
            timeo[itime]=dtime
           # precipitation
            pcp_path = os.path.join(root,f)
            print(pcp_path)
            pcp=gdal.Open(pcp_path)
            a=pcp.ReadAsArray()  #data
            pcpo[itime,:,:]=a
            itime=itime+1

nco.close()
# Out:
# 1981-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1981.01.tif
# 1981-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1981.02.tif
# 1981-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1981.03.tif
# 1981-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1981.04.tif
# 1981-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1981.05.tif
# 1981-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1981.06.tif
# 1981-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1981.07.tif
# 1981-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1981.08.tif
# 1981-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1981.09.tif
# 1981-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1981.10.tif
# 1981-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1981.11.tif
# 1981-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1981.12.tif
# 1982-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1982.01.tif
# 1982-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1982.02.tif
# 1982-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1982.03.tif
# 1982-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1982.04.tif
# 1982-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1982.05.tif
# 1982-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1982.06.tif
# 1982-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1982.07.tif
# 1982-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1982.08.tif
# 1982-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1982.09.tif
# 1982-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1982.10.tif
# 1982-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1982.11.tif
# 1982-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1982.12.tif
# 1983-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1983.01.tif
# 1983-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1983.02.tif
# 1983-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1983.03.tif
# 1983-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1983.04.tif
# 1983-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1983.05.tif
# 1983-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1983.06.tif
# 1983-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1983.07.tif
# 1983-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1983.08.tif
# 1983-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1983.09.tif
# 1983-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1983.10.tif
# 1983-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1983.11.tif
# 1983-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1983.12.tif
# 1984-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1984.01.tif
# 1984-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1984.02.tif
# 1984-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1984.03.tif
# 1984-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1984.04.tif
# 1984-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1984.05.tif
# 1984-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1984.06.tif
# 1984-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1984.07.tif
# 1984-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1984.08.tif
# 1984-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1984.09.tif
# 1984-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1984.10.tif
# 1984-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1984.11.tif
# 1984-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1984.12.tif
# 1985-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1985.01.tif
# 1985-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1985.02.tif
# 1985-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1985.03.tif
# 1985-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1985.04.tif
# 1985-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1985.05.tif
# 1985-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1985.06.tif
# 1985-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1985.07.tif
# 1985-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1985.08.tif
# 1985-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1985.09.tif
# 1985-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1985.10.tif
# 1985-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1985.11.tif
# 1985-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1985.12.tif
# 1986-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1986.01.tif
# 1986-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1986.02.tif
# 1986-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1986.03.tif
# 1986-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1986.04.tif
# 1986-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1986.05.tif
# 1986-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1986.06.tif
# 1986-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1986.07.tif
# 1986-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1986.08.tif
# 1986-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1986.09.tif
# 1986-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1986.10.tif
# 1986-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1986.11.tif
# 1986-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1986.12.tif
# 1987-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1987.01.tif
# 1987-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1987.02.tif
# 1987-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1987.03.tif
# 1987-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1987.04.tif
# 1987-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1987.05.tif
# 1987-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1987.06.tif
# 1987-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1987.07.tif
# 1987-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1987.08.tif
# 1987-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1987.09.tif
# 1987-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1987.10.tif
# 1987-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1987.11.tif
# 1987-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1987.12.tif
# 1988-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1988.01.tif
# 1988-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1988.02.tif
# 1988-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1988.03.tif
# 1988-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1988.04.tif
# 1988-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1988.05.tif
# 1988-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1988.06.tif
# 1988-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1988.07.tif
# 1988-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1988.08.tif
# 1988-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1988.09.tif
# 1988-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1988.10.tif
# 1988-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1988.11.tif
# 1988-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1988.12.tif
# 1989-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1989.01.tif
# 1989-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1989.02.tif
# 1989-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1989.03.tif
# 1989-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1989.04.tif
# 1989-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1989.05.tif
# 1989-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1989.06.tif
# 1989-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1989.07.tif
# 1989-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1989.08.tif
# 1989-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1989.09.tif
# 1989-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1989.10.tif
# 1989-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1989.11.tif
# 1989-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1989.12.tif
# 1990-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1990.01.tif
# 1990-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1990.02.tif
# 1990-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1990.03.tif
# 1990-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1990.04.tif
# 1990-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1990.05.tif
# 1990-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1990.06.tif
# 1990-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1990.07.tif
# 1990-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1990.08.tif
# 1990-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1990.09.tif
# 1990-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1990.10.tif
# 1990-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1990.11.tif
# 1990-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1990.12.tif
# 1991-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1991.01.tif
# 1991-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1991.02.tif
# 1991-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1991.03.tif
# 1991-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1991.04.tif
# 1991-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1991.05.tif
# 1991-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1991.06.tif
# 1991-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1991.07.tif
# 1991-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1991.08.tif
# 1991-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1991.09.tif
# 1991-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1991.10.tif
# 1991-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1991.11.tif
# 1991-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1991.12.tif
# 1992-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1992.01.tif
# 1992-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1992.02.tif
# 1992-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1992.03.tif
# 1992-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1992.04.tif
# 1992-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1992.05.tif
# 1992-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1992.06.tif
# 1992-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1992.07.tif
# 1992-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1992.08.tif
# 1992-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1992.09.tif
# 1992-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1992.10.tif
# 1992-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1992.11.tif
# 1992-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1992.12.tif
# 1993-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1993.01.tif
# 1993-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1993.02.tif
# 1993-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1993.03.tif
# 1993-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1993.04.tif
# 1993-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1993.05.tif
# 1993-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1993.06.tif
# 1993-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1993.07.tif
# 1993-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1993.08.tif
# 1993-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1993.09.tif
# 1993-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1993.10.tif
# 1993-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1993.11.tif
# 1993-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1993.12.tif
# 1994-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1994.01.tif
# 1994-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1994.02.tif
# 1994-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1994.03.tif
# 1994-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1994.04.tif
# 1994-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1994.05.tif
# 1994-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1994.06.tif
# 1994-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1994.07.tif
# 1994-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1994.08.tif
# 1994-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1994.09.tif
# 1994-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1994.10.tif
# 1994-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1994.11.tif
# 1994-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1994.12.tif
# 1995-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1995.01.tif
# 1995-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1995.02.tif
# 1995-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1995.03.tif
# 1995-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1995.04.tif
# 1995-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1995.05.tif
# 1995-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1995.06.tif
# 1995-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1995.07.tif
# 1995-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1995.08.tif
# 1995-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1995.09.tif
# 1995-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1995.10.tif
# 1995-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1995.11.tif
# 1995-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1995.12.tif
# 1996-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1996.01.tif
# 1996-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1996.02.tif
# 1996-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1996.03.tif
# 1996-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1996.04.tif
# 1996-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1996.05.tif
# 1996-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1996.06.tif
# 1996-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1996.07.tif
# 1996-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1996.08.tif
# 1996-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1996.09.tif
# 1996-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1996.10.tif
# 1996-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1996.11.tif
# 1996-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1996.12.tif
# 1997-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1997.01.tif
# 1997-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1997.02.tif
# 1997-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1997.03.tif
# 1997-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1997.04.tif
# 1997-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1997.05.tif
# 1997-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1997.06.tif
# 1997-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1997.07.tif
# 1997-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1997.08.tif
# 1997-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1997.09.tif
# 1997-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1997.10.tif
# 1997-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1997.11.tif
# 1997-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1997.12.tif
# 1998-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1998.01.tif
# 1998-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1998.02.tif
# 1998-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1998.03.tif
# 1998-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1998.04.tif
# 1998-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1998.05.tif
# 1998-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1998.06.tif
# 1998-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1998.07.tif
# 1998-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1998.08.tif
# 1998-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1998.09.tif
# 1998-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1998.10.tif
# 1998-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1998.11.tif
# 1998-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1998.12.tif
# 1999-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1999.01.tif
# 1999-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1999.02.tif
# 1999-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1999.03.tif
# 1999-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1999.04.tif
# 1999-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1999.05.tif
# 1999-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1999.06.tif
# 1999-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1999.07.tif
# 1999-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1999.08.tif
# 1999-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1999.09.tif
# 1999-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1999.10.tif
# 1999-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1999.11.tif
# 1999-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.1999.12.tif
# 2000-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2000.01.tif
# 2000-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2000.02.tif
# 2000-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2000.03.tif
# 2000-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2000.04.tif
# 2000-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2000.05.tif
# 2000-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2000.06.tif
# 2000-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2000.07.tif
# 2000-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2000.08.tif
# 2000-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2000.09.tif
# 2000-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2000.10.tif
# 2000-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2000.11.tif
# 2000-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2000.12.tif
# 2001-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2001.01.tif
# 2001-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2001.02.tif
# 2001-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2001.03.tif
# 2001-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2001.04.tif
# 2001-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2001.05.tif
# 2001-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2001.06.tif
# 2001-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2001.07.tif
# 2001-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2001.08.tif
# 2001-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2001.09.tif
# 2001-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2001.10.tif
# 2001-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2001.11.tif
# 2001-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2001.12.tif
# 2002-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2002.01.tif
# 2002-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2002.02.tif
# 2002-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2002.03.tif
# 2002-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2002.04.tif
# 2002-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2002.05.tif
# 2002-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2002.06.tif
# 2002-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2002.07.tif
# 2002-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2002.08.tif
# 2002-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2002.09.tif
# 2002-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2002.10.tif
# 2002-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2002.11.tif
# 2002-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2002.12.tif
# 2003-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2003.01.tif
# 2003-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2003.02.tif
# 2003-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2003.03.tif
# 2003-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2003.04.tif
# 2003-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2003.05.tif
# 2003-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2003.06.tif
# 2003-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2003.07.tif
# 2003-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2003.08.tif
# 2003-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2003.09.tif
# 2003-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2003.10.tif
# 2003-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2003.11.tif
# 2003-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2003.12.tif
# 2004-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2004.01.tif
# 2004-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2004.02.tif
# 2004-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2004.03.tif
# 2004-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2004.04.tif
# 2004-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2004.05.tif
# 2004-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2004.06.tif
# 2004-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2004.07.tif
# 2004-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2004.08.tif
# 2004-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2004.09.tif
# 2004-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2004.10.tif
# 2004-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2004.11.tif
# 2004-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2004.12.tif
# 2005-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2005.01.tif
# 2005-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2005.02.tif
# 2005-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2005.03.tif
# 2005-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2005.04.tif
# 2005-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2005.05.tif
# 2005-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2005.06.tif
# 2005-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2005.07.tif
# 2005-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2005.08.tif
# 2005-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2005.09.tif
# 2005-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2005.10.tif
# 2005-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2005.11.tif
# 2005-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2005.12.tif
# 2006-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2006.01.tif
# 2006-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2006.02.tif
# 2006-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2006.03.tif
# 2006-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2006.04.tif
# 2006-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2006.05.tif
# 2006-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2006.06.tif
# 2006-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2006.07.tif
# 2006-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2006.08.tif
# 2006-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2006.09.tif
# 2006-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2006.10.tif
# 2006-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2006.11.tif
# 2006-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2006.12.tif
# 2007-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2007.01.tif
# 2007-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2007.02.tif
# 2007-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2007.03.tif
# 2007-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2007.04.tif
# 2007-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2007.05.tif
# 2007-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2007.06.tif
# 2007-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2007.07.tif
# 2007-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2007.08.tif
# 2007-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2007.09.tif
# 2007-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2007.10.tif
# 2007-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2007.11.tif
# 2007-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2007.12.tif
# 2008-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2008.01.tif
# 2008-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2008.02.tif
# 2008-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2008.03.tif
# 2008-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2008.04.tif
# 2008-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2008.05.tif
# 2008-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2008.06.tif
# 2008-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2008.07.tif
# 2008-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2008.08.tif
# 2008-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2008.09.tif
# 2008-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2008.10.tif
# 2008-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2008.11.tif
# 2008-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2008.12.tif
# 2009-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2009.01.tif
# 2009-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2009.02.tif
# 2009-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2009.03.tif
# 2009-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2009.04.tif
# 2009-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2009.05.tif
# 2009-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2009.06.tif
# 2009-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2009.07.tif
# 2009-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2009.08.tif
# 2009-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2009.09.tif
# 2009-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2009.10.tif
# 2009-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2009.11.tif
# 2009-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2009.12.tif
# 2010-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2010.01.tif
# 2010-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2010.02.tif
# 2010-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2010.03.tif
# 2010-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2010.04.tif
# 2010-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2010.05.tif
# 2010-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2010.06.tif
# 2010-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2010.07.tif
# 2010-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2010.08.tif
# 2010-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2010.09.tif
# 2010-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2010.10.tif
# 2010-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2010.11.tif
# 2010-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2010.12.tif
# 2011-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2011.01.tif
# 2011-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2011.02.tif
# 2011-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2011.03.tif
# 2011-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2011.04.tif
# 2011-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2011.05.tif
# 2011-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2011.06.tif
# 2011-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2011.07.tif
# 2011-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2011.08.tif
# 2011-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2011.09.tif
# 2011-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2011.10.tif
# 2011-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2011.11.tif
# 2011-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2011.12.tif
# 2012-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2012.01.tif
# 2012-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2012.02.tif
# 2012-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2012.03.tif
# 2012-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2012.04.tif
# 2012-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2012.05.tif
# 2012-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2012.06.tif
# 2012-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2012.07.tif
# 2012-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2012.08.tif
# 2012-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2012.09.tif
# 2012-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2012.10.tif
# 2012-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2012.11.tif
# 2012-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2012.12.tif
# 2013-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2013.01.tif
# 2013-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2013.02.tif
# 2013-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2013.03.tif
# 2013-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2013.04.tif
# 2013-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2013.05.tif
# 2013-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2013.06.tif
# 2013-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2013.07.tif
# 2013-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2013.08.tif
# 2013-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2013.09.tif
# 2013-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2013.10.tif
# 2013-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2013.11.tif
# 2013-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2013.12.tif
# 2014-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2014.01.tif
# 2014-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2014.02.tif
# 2014-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2014.03.tif
# 2014-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2014.04.tif
# 2014-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2014.05.tif
# 2014-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2014.06.tif
# 2014-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2014.07.tif
# 2014-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2014.08.tif
# 2014-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2014.09.tif
# 2014-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2014.10.tif
# 2014-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2014.11.tif
# 2014-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2014.12.tif
# 2015-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2015.01.tif
# 2015-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2015.02.tif
# 2015-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2015.03.tif
# 2015-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2015.04.tif
# 2015-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2015.05.tif
# 2015-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2015.06.tif
# 2015-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2015.07.tif
# 2015-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2015.08.tif
# 2015-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2015.09.tif
# 2015-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2015.10.tif
# 2015-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2015.11.tif
# 2015-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2015.12.tif
# 2016-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2016.01.tif
# 2016-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2016.02.tif
# 2016-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2016.03.tif
# 2016-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2016.04.tif
# 2016-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2016.05.tif
# 2016-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2016.06.tif
# 2016-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2016.07.tif
# 2016-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2016.08.tif
# 2016-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2016.09.tif
# 2016-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2016.10.tif
# 2016-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2016.11.tif
# 2016-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2016.12.tif
# 2017-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2017.01.tif
# 2017-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2017.02.tif
# 2017-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2017.03.tif
# 2017-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2017.04.tif
# 2017-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2017.05.tif
# 2017-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2017.06.tif
# 2017-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2017.07.tif
# 2017-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2017.08.tif
# 2017-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2017.09.tif
# 2017-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2017.10.tif
# 2017-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2017.11.tif
# 2017-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2017.12.tif
# 2018-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2018.01.tif
# 2018-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2018.02.tif
# 2018-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2018.03.tif
# 2018-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2018.04.tif
# 2018-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2018.05.tif
# 2018-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2018.06.tif
# 2018-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2018.07.tif
# 2018-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2018.08.tif
# 2018-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2018.09.tif
# 2018-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2018.10.tif
# 2018-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2018.11.tif
# 2018-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2018.12.tif
# 2019-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2019.01.tif
# 2019-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2019.02.tif
# 2019-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2019.03.tif
# 2019-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2019.04.tif
# 2019-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2019.05.tif
# 2019-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2019.06.tif
# 2019-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2019.07.tif
# 2019-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2019.08.tif
# 2019-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2019.09.tif
# 2019-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2019.10.tif
# 2019-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2019.11.tif
# 2019-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2019.12.tif
# 2020-01-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2020.01.tif
# 2020-02-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2020.02.tif
# 2020-03-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2020.03.tif
# 2020-04-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2020.04.tif
# 2020-05-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2020.05.tif
# 2020-06-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2020.06.tif
# 2020-07-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2020.07.tif
# 2020-08-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2020.08.tif
# 2020-09-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2020.09.tif
# 2020-10-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2020.10.tif
# 2020-11-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2020.11.tif
# 2020-12-01 00:00:00
# /Users/bennyistanto/Temp/CHIRPS/SPI/IDN/Java/java_chirps-v2.0.2020.12.tif
